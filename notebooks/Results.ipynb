# %% [markdown]
# # Results
# In this notebook we analyze the results of the quantum reservoirs subject to thermal noise and compare against three other noise models.

# %%
import warnings
import numpy as np
import umap, random, pickle
from tqdm import tqdm 
from os import listdir
from os.path import isfile, join
import pandas as pd

from scipy.stats import unitary_group
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from mpl_toolkits.axes_grid1 import make_axes_locatable

from qiskit.quantum_info import pauli_basis, Pauli, SparsePauliOp
from qiskit.circuit.library import Diagonal, UnitaryGate
from qiskit import QuantumCircuit
from qiskit.compiler import transpile
from qiskit_aer import AerSimulator



warnings.filterwarnings('ignore')

# %% [markdown]
# ## Performance results
#
# We now analyze the performance of the quantum reservoirs for the amplitude damping noise, the depolarizing noise and the phase damping noise. The task consists of predictinng the excited state energy of the LiH molecule.

# %%
with open('../training_data/spectrums_LiH.npy', 'rb') as f:
            spectrums = np.load(f)
with open('../training_data/bond_lengths_LiH.npy', 'rb') as f:
            bond_lengths = np.load(f)
with open('../training_data/ground_states_LiH.npy', 'rb') as f:
            ground_states = np.load(f)
        
num_states = ground_states.shape[0]
y = np.zeros((num_states, 2))
y[:,0] = spectrums[:,1] - spectrums[:,0]
y[:,1] = spectrums[:,2] - spectrums[:,0]

# %% [markdown]
# ## 1. Amplitude damping

# %%
path = []
files = []
names = []
for noise in ['0','0001','0005','001', '003']:
    for gates in ['25','35','45','55','65','75','85','95','105','115','125','135','145',
                  '155','165','175','185','195','205','215', '300', '500', '700', '900' ]:
        if noise!='0':
            path_name = '../results/partial_noise/G3/amplitude_damping/'+noise+'/'+gates+'/'
        else:
            path_name = '../results/partial_noise/G3/amplitude_damping/'+noise+'/'+gates+'/'
        files_names = [f for f in listdir(path_name) if isfile(join(path_name, f))]
        names.append('AD_'+ noise +'_'+gates)
        path.append(path_name)
        files.append(files_names)

# %% [markdown]
# ### Prediction errors

# %%
alpha = 1e-9
alpha2 = 1e-9
mses1 = []
mses2 = []
for i in tqdm(range(len(files))):
    file_list = files[i]
    mse_list1 = []  
    mse_list2 = [] 
    for file in file_list:
        #try:
            # Load results
            with open(path[i] + file, 'rb') as f:
                obs_res = np.load(f, allow_pickle=True) 
            try:
                non_zero_obs = [~np.isclose(obs_res[:,j],0).all() for j in range(obs_res.shape[1])]
            except:
                obs_res = obs_res.tolist()['observables_noise']
                non_zero_obs = [~np.isclose(obs_res[:,j],0).all() for j in range(obs_res.shape[1])]
            if sum(non_zero_obs)>0:
                obs_res = obs_res[:,non_zero_obs]
            obs_res = obs_res[:, ~np.isnan(obs_res).any(axis=0)]
            # Separate train and test uniformly
            size = obs_res.shape[0]
            idx1 = int(0.2*size)
            idx2 = int(0.5*size)
            train_idx=list(range(idx1)) + list(range(idx2, size))
            X_train, y_train, bond_lengths_train = obs_res[train_idx], y[train_idx], bond_lengths[train_idx]
            X_test, y_test, bond_lengths_test = obs_res[idx1:idx2], y[idx1:idx2], bond_lengths[idx1:idx2]
            #X_train, X_test, y_train, y_test, bond_lengths_train, bond_lengths_test = train_test_split( 
            #        obs_res, y, bond_lengths, test_size=0.33, random_state=42)
            # Scale target
            scaler = MinMaxScaler()
            y_train_scaled = scaler.fit_transform(y_train)
            y_test_scaled = scaler.transform(y_test)
            # Fit linear model
            alpha_sel = alpha if i>24 else alpha2
            lm1 = Ridge(alpha=alpha_sel)
            lm1.fit(X_train, y_train_scaled[:,0])
            lm2 = Ridge(alpha=alpha_sel)
            lm2.fit(X_train, y_train_scaled[:,1])
            # Predict
            y_hat1 = lm1.predict(X_test)
            y_hat2 = lm2.predict(X_test)
            y_hat = np.vstack([y_hat1, y_hat2]).T
            y_hat = scaler.inverse_transform(y_hat)
            
            
            idx_rm = (y_hat[:,0]>0.09) | (y_hat[:,0]<0.0)
            y_hat_n = y_hat[~idx_rm,0]
            y_test_n = y_test[~idx_rm,0]
            
            idx_rm2 = (y_hat[:,1]>0.15) | (y_hat[:,1]<0.05)
            y_hat_n2 = y_hat[~idx_rm,1]
            y_test_n2 = y_test[~idx_rm,1]
            # MSE
            mse1 = np.mean(np.square(y_hat_n - y_test_n))
            mse2 = np.mean(np.square(y_hat_n2 - y_test_n2))
            mse_list1.append(mse1)
            mse_list2.append(mse2)
        #except:
        #    print(path[i] + file)
    mses1.append(mse_list1)
    mses2.append(mse_list2)

mses1 = [np.mean(mse) for mse in mses1]
mses2 = [np.mean(mse) for mse in mses2]

results = pd.DataFrame([mses1, mses2], columns=names, index=['MSE1', 'MSE2']).T
#results.to_csv('mse_amplitude_damping.csv')
# Out:
# 100%|███████████████████████████████████████████████████████| 120/120 [01:59<00:00,  1.01it/s]

# %%
from matplotlib.patches import Rectangle
from mpl_toolkits.axes_grid1 import make_axes_locatable

x = [25,35,45,55,65,75,85,95,105,115,125,135,145,155,165,175,185,195,205,300,500,700,900]
colors = ['lightskyblue', 'lightcoral', 'turquoise', 'black', 'gold', 'orange', 'lightgreen', 'mediumpurple']

#LIH '0','0001','0005','001', '003'
mses_AD_0001 = results['MSE1'][['AD_0001_'+ str(n) for n in x]]
mses_AD_0005 = results['MSE1'][['AD_0005_'+ str(n) for n in x]]
mses_AD_003 = results['MSE1'][['AD_003_'+ str(n) for n in x]]
mses_AD_001 = results['MSE1'][['AD_001_'+ str(n) for n in x]]
mses_AD_0 = results['MSE1'][['AD_0_'+ str(n) for n in x]]


fig, (ax1) = plt.subplots(1, 1,figsize = (15,10))

ax1.plot(x, mses_AD_0001, marker='o', color = colors[0], label ='AD 0.0001')
ax1.plot(x, mses_AD_0005, marker='o', color = colors[2], label ='AD 0.0005')
ax1.plot(x, mses_AD_003, marker='o', color = colors[1], label ='AD 0.003')
ax1.plot(x, mses_AD_001, marker='o', color = colors[4], label ='AD 0.001')
ax1.plot(x, mses_AD_0, marker='o', color = colors[5], label ='AD 0')


ax1.set_yscale('log')
ax1.set_xscale('linear')
ax1.set_xlim((20,205))

ax1.set_xlabel('Number of Gates',fontsize=14)
ax1.set_ylabel('Mean squared error',fontsize=14)
ax1.legend()

divider = make_axes_locatable(ax1)
ax2 = divider.append_axes("right", size=3, pad=0, sharey=ax1)
ax2.set_xscale('log')
ax2.set_xlim((205,1000))
ax2.spines['left'].set_visible(False)
ax2.yaxis.set_visible(False)
ax2.set_xticks([300,500,700,900], ['300','500','700', '900'], minor=False)
#plt.setp(ax2.get_xticklabels(), visible=True)
plt.minorticks_off()


ax2.plot(x, mses_AD_0001, marker='o', color = colors[0], label ='AD 0.0001')
ax2.plot(x, mses_AD_0005, marker='o', color = colors[2], label ='AD 0.0005')
ax2.plot(x, mses_AD_001, marker='o', color = colors[4], label ='AD 0.001')
ax2.plot(x, mses_AD_003, marker='o', color = colors[1], label ='AD 0.003')
ax2.plot(x, mses_AD_0, marker='o', color = colors[5], label ='AD 0')

plt.show()

# %% [markdown]
# ### Fidelity

# %%
path = []
files = []
names = []
for noise in ['0001','0005','001', '003']:
    for gates in ['25','35','45','55','65','75','85','95','105','115','125','135','145',
                  '155','165','175','185','195','205','215', '300', '500', '700', '900' ]:
        path_name = '../results/partial_noise/G3/amplitude_damping/'+noise+'/'+gates+'/'
        files_names = [f for f in listdir(path_name) if isfile(join(path_name, f))]
        names.append('AD_'+ noise +'_'+gates)
        path.append(path_name)
        files.append(files_names)

# %%
fidelity = []
mse_obs = []
for i in tqdm(range(len(files))):
    file_list = files[i]
    fidelity_list = []  
    mse_obs_list = []
    for file in file_list:
        # Load results
        with open(path[i] + file, 'rb') as f:
            result = np.load(f, allow_pickle=True) 
        f = np.array(result.tolist()['fidelity_list'])
        mean_fidelity = np.mean(f)
        fidelity_list.append(mean_fidelity)

    fidelity.append(fidelity_list)
    
fidelity = [np.mean(f) for f in fidelity]
fidelity_results = pd.DataFrame([fidelity], columns=names, index=['fidelity']).T
#fidelity_results.to_csv('fidelity_amplitude_damping.csv')
# Out:
# 100%|█████████████████████████████████████████████████████████| 96/96 [00:02<00:00, 43.69it/s]

# %%
from matplotlib.patches import Rectangle

x = [25,35,45,55,65,75,85,95,105,115,125,135,145,155,165,175,185,195,205,215,300,500, 700, 900 ]
colors = ['lightskyblue', 'lightcoral', 'turquoise', 'black', 'gold', 'orange', 'lightgreen', 'mediumpurple']

#LIH
fidelity_AD_0001 = fidelity_results['fidelity'][['AD_0001_'+ str(n) for n in x]]
fidelity_AD_0005 = fidelity_results['fidelity'][['AD_0005_'+ str(n) for n in x]]
fidelity_AD_001 = fidelity_results['fidelity'][['AD_001_'+ str(n) for n in x]]
fidelity_AD_003 = fidelity_results['fidelity'][['AD_003_'+ str(n) for n in x]]

fig, (ax1) = plt.subplots(1, 1,figsize = (15,10))

ax1.plot(x, fidelity_AD_0001, marker='o', color = colors[0], label ='AD 0.0001')
ax1.plot(x, fidelity_AD_0005, marker='o', color = colors[2], label ='AD 0.0005')
ax1.plot(x, fidelity_AD_001, marker='o', color = colors[4], label ='AD 0.001')
ax1.plot(x, fidelity_AD_003, marker='o', color = colors[1], label ='AD 0.003')
ax1.legend()
#ax1.set_yscale('log')
ax1.tick_params(axis='both',labelsize=15)
ax1.set_yticks([0.99,  0.97, 0.95, 0.93, 0.91, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3,0.2]) #,labelsize=25

ax1.set_xlabel('Number of Gates',fontsize=18)
ax1.set_ylabel('Fidelity',fontsize=18)
ax1.set_xlim((20,205))
ax1.legend()
plt.title('Fidelity Amplitude damping', fontsize=20)

divider = make_axes_locatable(ax1)
ax2 = divider.append_axes("right", size=3, pad=0, sharey=ax1)
ax2.set_xscale('log')
ax2.set_xlim((205,1000))
ax2.spines['left'].set_visible(False)
ax2.yaxis.set_visible(False)
ax2.set_xticks([300,500,700,900], ['300','500','700', '900'], minor=False, fontsize=18)
#plt.setp(ax2.get_xticklabels(), visible=True)
plt.minorticks_off()
ax2.plot(x, fidelity_AD_0001, marker='o', color = colors[0], label ='AD 0.0001')
ax2.plot(x, fidelity_AD_0005, marker='o', color = colors[2], label ='AD 0.0005')
ax2.plot(x, fidelity_AD_001, marker='o', color = colors[4], label ='AD 0.001')
ax2.plot(x, fidelity_AD_003, marker='o', color = colors[1], label ='AD 0.003')


plt.show()

# %% [markdown]
# ## 2. Depolarizing noise

# %%
path = []
files = []
names = []
for noise in ['0','0001','0005','001', '003']:
    for gates in ['25','35','45','55','65','75','85','95','105','115','125','135','145',
                  '155','165','175','185','195','205','215', '300', '500', '700', '900' ]:
        if noise!='0':
            path_name = '../results/partial_noise/G3/depolarizing/'+noise+'/'+gates+'/'
        else:
            path_name = '../results/partial_noise/G3/amplitude_damping/'+noise+'/'+gates+'/'
        files_names = [f for f in listdir(path_name) if isfile(join(path_name, f))]
        names.append('DP_'+ noise +'_'+gates)
        path.append(path_name)
        files.append(files_names)

# %% [markdown]
# ### Prediction errors

# %%
alpha = 1e-8
alpha2 = 1e-9
mses1 = []
mses2 = []
for i in tqdm(range(len(files))):
    file_list = files[i]
    mse_list1 = []  
    mse_list2 = [] 
    for file in file_list:
        #try:
            # Load results
            with open(path[i] + file, 'rb') as f:
                obs_res = np.load(f, allow_pickle=True) 
            try:
                non_zero_obs = [~np.isclose(obs_res[:,j],0).all() for j in range(obs_res.shape[1])]
            except:
                obs_res = obs_res.tolist()['observables_noise']
                non_zero_obs = [~np.isclose(obs_res[:,j],0).all() for j in range(obs_res.shape[1])]
            if sum(non_zero_obs)>0:
                obs_res = obs_res[:,non_zero_obs]
            obs_res = obs_res[:, ~np.isnan(obs_res).any(axis=0)]
            # Separate train and test uniformly
            size = obs_res.shape[0]
            idx1 = int(0.2*size)
            idx2 = int(0.5*size)
            train_idx=list(range(idx1)) + list(range(idx2, size))
            X_train, y_train, bond_lengths_train = obs_res[train_idx], y[train_idx], bond_lengths[train_idx]
            X_test, y_test, bond_lengths_test = obs_res[idx1:idx2], y[idx1:idx2], bond_lengths[idx1:idx2]
            #X_train, X_test, y_train, y_test, bond_lengths_train, bond_lengths_test = train_test_split( 
            #        obs_res, y, bond_lengths, test_size=0.33, random_state=42)
            # Scale target
            scaler = MinMaxScaler()
            y_train_scaled = scaler.fit_transform(y_train)
            y_test_scaled = scaler.transform(y_test)
            # Fit linear model
            alpha_sel = alpha if i>24 else alpha2
            lm1 = Ridge(alpha=alpha_sel)
            lm1.fit(X_train, y_train_scaled[:,0])
            lm2 = Ridge(alpha=alpha_sel)
            lm2.fit(X_train, y_train_scaled[:,1])
            # Predict
            y_hat1 = lm1.predict(X_test)
            y_hat2 = lm2.predict(X_test)
            y_hat = np.vstack([y_hat1, y_hat2]).T
            y_hat = scaler.inverse_transform(y_hat)
            
            
            idx_rm = (y_hat[:,0]>0.09) | (y_hat[:,0]<0.0)
            y_hat_n = y_hat[~idx_rm,0]
            y_test_n = y_test[~idx_rm,0]
            
            idx_rm2 = (y_hat[:,1]>0.15) | (y_hat[:,1]<0.05)
            y_hat_n2 = y_hat[~idx_rm,1]
            y_test_n2 = y_test[~idx_rm,1]
            # MSE
            mse1 = np.mean(np.square(y_hat_n - y_test_n))
            mse2 = np.mean(np.square(y_hat_n2 - y_test_n2))
            mse_list1.append(mse1)
            mse_list2.append(mse2)
        #except:
        #    print(path[i] + file)
    mses1.append(mse_list1)
    mses2.append(mse_list2)

mses1 = [np.mean(mse) for mse in mses1]
mses2 = [np.mean(mse) for mse in mses2]

results = pd.DataFrame([mses1, mses2], columns=names, index=['MSE1', 'MSE2']).T
#results.to_csv('mse_depolarizing.csv')
# Out:
# 100%|███████████████████████████████████████████████████████| 120/120 [01:22<00:00,  1.45it/s]

# %%
from matplotlib.patches import Rectangle
from mpl_toolkits.axes_grid1 import make_axes_locatable

x = [25,35,45,55,65,75,85,95,105,115,125,135,145,155,165,175,185,195,205,300,500,700,900]
colors = ['lightskyblue', 'lightcoral', 'turquoise', 'black', 'gold', 'orange', 'lightgreen', 'mediumpurple']

#LIH 
mses_DP_0001 = results['MSE1'][['DP_0001_'+ str(n) for n in x]]
mses_DP_0005 = results['MSE1'][['DP_0005_'+ str(n) for n in x]]
mses_DP_003 = results['MSE1'][['DP_003_'+ str(n) for n in x]]
mses_DP_001 = results['MSE1'][['DP_001_'+ str(n) for n in x]]
mses_DP_0 = results['MSE1'][['DP_0_'+ str(n) for n in x]]


fig, (ax1) = plt.subplots(1, 1,figsize = (15,10))

ax1.plot(x, mses_DP_0001, marker='o', color = colors[0], label ='DP 0.0001')
ax1.plot(x, mses_DP_0005, marker='o', color = colors[2], label ='DP 0.0005')
ax1.plot(x, mses_DP_003, marker='o', color = colors[1], label ='DP 0.003')
ax1.plot(x, mses_DP_001, marker='o', color = colors[4], label ='DP 0.001')
ax1.plot(x, mses_DP_0, marker='o', color = colors[5], label ='DP 0')


ax1.set_yscale('log')
ax1.set_xscale('linear')
ax1.set_xlim((20,205))

ax1.set_xlabel('Number of Gates',fontsize=14)
ax1.set_ylabel('Mean squared error',fontsize=14)
ax1.legend()

divider = make_axes_locatable(ax1)
ax2 = divider.append_axes("right", size=3, pad=0, sharey=ax1)
ax2.set_xscale('log')
ax2.set_xlim((205,1000))
ax2.spines['left'].set_visible(False)
ax2.yaxis.set_visible(False)
ax2.set_xticks([300,500,700,900], ['300','500','700', '900'], minor=False)
plt.minorticks_off()


ax2.plot(x, mses_DP_0001, marker='o', color = colors[0], label ='DP 0.0001')
ax2.plot(x, mses_DP_0005, marker='o', color = colors[2], label ='DP 0.0005')
ax2.plot(x, mses_DP_003, marker='o', color = colors[1], label ='DP 0.003')
ax2.plot(x, mses_DP_001, marker='o', color = colors[4], label ='DP 0.001')
ax2.plot(x, mses_DP_0, marker='o', color = colors[5], label ='DP 0')

plt.show()

# %% [markdown]
# ### Fidelity

# %%
path = []
files = []
names = []
for noise in ['0001','0005','001', '003']:
    for gates in ['25','35','45','55','65','75','85','95','105','115','125','135','145',
                  '155','165','175','185','195','205','215', '300', '500', '700', '900' ]:
        path_name = '../results/partial_noise/G3/depolarizing/'+noise+'/'+gates+'/'
        files_names = [f for f in listdir(path_name) if isfile(join(path_name, f))]
        names.append('DP_'+ noise +'_'+gates)
        path.append(path_name)
        files.append(files_names)

# %%
fidelity = []
mse_obs = []
for i in tqdm(range(len(files))):
    file_list = files[i]
    fidelity_list = []  
    mse_obs_list = []
    for file in file_list:
        # Load results
        with open(path[i] + file, 'rb') as f:
            result = np.load(f, allow_pickle=True) 
        f = np.array(result.tolist()['fidelity_list'])
        mean_fidelity = np.mean(f)
        fidelity_list.append(mean_fidelity)

    fidelity.append(fidelity_list)
    
fidelity = [np.mean(f) for f in fidelity]
fidelity_results = pd.DataFrame([fidelity], columns=names, index=['fidelity']).T
#fidelity_results.to_csv('fidelity_depolarizing.csv')
# Out:
# 100%|██████████| 96/96 [00:05<00:00, 17.74it/s]

# %%
from matplotlib.patches import Rectangle

x = [25,35,45,55,65,75,85,95,105,115,125,135,145,155,165,175,185,195,205,215,300,500, 700, 900 ]
colors = ['lightskyblue', 'lightcoral', 'turquoise', 'black', 'gold', 'orange', 'lightgreen', 'mediumpurple']

#LIH
fidelity_DP_0001 = fidelity_results['fidelity'][['DP_0001_'+ str(n) for n in x]]
fidelity_DP_0005 = fidelity_results['fidelity'][['DP_0005_'+ str(n) for n in x]]
fidelity_DP_001 = fidelity_results['fidelity'][['DP_001_'+ str(n) for n in x]]
fidelity_DP_003 = fidelity_results['fidelity'][['DP_003_'+ str(n) for n in x]]

fig, (ax1) = plt.subplots(1, 1,figsize = (15,10))

ax1.plot(x, fidelity_DP_0001, marker='o', color = colors[0], label ='DP 0.0001')
ax1.plot(x, fidelity_DP_0005, marker='o', color = colors[2], label ='DP 0.0005')
ax1.plot(x, fidelity_DP_001, marker='o', color = colors[4], label ='DP 0.001')
ax1.plot(x, fidelity_DP_003, marker='o', color = colors[1], label ='DP 0.003')
ax1.legend()
#ax1.set_yscale('log')
ax1.tick_params(axis='both',labelsize=15)
ax1.set_yticks([0.99,  0.97, 0.95, 0.93, 0.91, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3,0.2]) #,labelsize=25

ax1.set_xlabel('Number of Gates',fontsize=18)
ax1.set_ylabel('Fidelity',fontsize=18)
ax1.set_xlim((20,205))
ax1.legend()
plt.title('Fidelity Depolarizing', fontsize=20)

divider = make_axes_locatable(ax1)
ax2 = divider.append_axes("right", size=3, pad=0, sharey=ax1)
ax2.set_xscale('log')
ax2.set_xlim((205,1000))
ax2.spines['left'].set_visible(False)
ax2.yaxis.set_visible(False)
ax2.set_xticks([300,500,700,900], ['300','500','700', '900'], minor=False, fontsize=18)

plt.minorticks_off()
ax2.plot(x, fidelity_DP_0001, marker='o', color = colors[0], label ='DP 0.0001')
ax2.plot(x, fidelity_DP_0005, marker='o', color = colors[2], label ='DP 0.0005')
ax2.plot(x, fidelity_DP_001, marker='o', color = colors[4], label ='DP 0.001')
ax2.plot(x, fidelity_DP_003, marker='o', color = colors[1], label ='DP 0.003')

plt.show()

# %% [markdown]
# ## 3. Phase damping

# %%
path = []
files = []
names = []
for noise in ['0','0001','0005','001', '003']:
    for gates in ['25','35','45','55','65','75','85','95','105','115','125','135','145',
                  '155','165','175','185','195','205','215', '300', '500', '700', '900' ]:
        if noise!='0':
            path_name = '../results/partial_noise/G3/phase_damping/'+noise+'/'+gates+'/'
        else:
            path_name = '../results/partial_noise/G3/amplitude_damping/'+noise+'/'+gates+'/'
        files_names = [f for f in listdir(path_name) if isfile(join(path_name, f))]
        names.append('PD_'+ noise +'_'+gates)
        path.append(path_name)
        files.append(files_names)

# %% [markdown]
# ### Prediction errors

# %%
alpha = 1e-9
alpha2 = 1e-9
mses1 = []
mses2 = []
for i in tqdm(range(len(files))):
    file_list = files[i]
    mse_list1 = []  
    mse_list2 = [] 
    for file in file_list:
        #try:
            # Load results
            with open(path[i] + file, 'rb') as f:
                obs_res = np.load(f, allow_pickle=True) 
            try:
                non_zero_obs = [~np.isclose(obs_res[:,j],0).all() for j in range(obs_res.shape[1])]
            except:
                obs_res = obs_res.tolist()['observables_noise']
                non_zero_obs = [~np.isclose(obs_res[:,j],0).all() for j in range(obs_res.shape[1])]
            if sum(non_zero_obs)>0:
                obs_res = obs_res[:,non_zero_obs]
            obs_res = obs_res[:, ~np.isnan(obs_res).any(axis=0)]
            # Separate train and test uniformly
            size = obs_res.shape[0]
            idx1 = int(0.2*size)
            idx2 = int(0.5*size)
            train_idx=list(range(idx1)) + list(range(idx2, size))
            X_train, y_train, bond_lengths_train = obs_res[train_idx], y[train_idx], bond_lengths[train_idx]
            X_test, y_test, bond_lengths_test = obs_res[idx1:idx2], y[idx1:idx2], bond_lengths[idx1:idx2]
            #X_train, X_test, y_train, y_test, bond_lengths_train, bond_lengths_test = train_test_split( 
            #        obs_res, y, bond_lengths, test_size=0.33, random_state=42)
            # Scale target
            scaler = MinMaxScaler()
            y_train_scaled = scaler.fit_transform(y_train)
            y_test_scaled = scaler.transform(y_test)
            # Fit linear model
            alpha_sel = alpha if i>24 else alpha2
            lm1 = Ridge(alpha=alpha_sel)
            lm1.fit(X_train, y_train_scaled[:,0])
            lm2 = Ridge(alpha=alpha_sel)
            lm2.fit(X_train, y_train_scaled[:,1])
            # Predict
            y_hat1 = lm1.predict(X_test)
            y_hat2 = lm2.predict(X_test)
            y_hat = np.vstack([y_hat1, y_hat2]).T
            y_hat = scaler.inverse_transform(y_hat)
            
            
            idx_rm = (y_hat[:,0]>0.09) | (y_hat[:,0]<0.0)
            y_hat_n = y_hat[~idx_rm,0]
            y_test_n = y_test[~idx_rm,0]
            
            idx_rm2 = (y_hat[:,1]>0.15) | (y_hat[:,1]<0.05)
            y_hat_n2 = y_hat[~idx_rm,1]
            y_test_n2 = y_test[~idx_rm,1]
            # MSE
            mse1 = np.mean(np.square(y_hat_n - y_test_n))
            mse2 = np.mean(np.square(y_hat_n2 - y_test_n2))
            mse_list1.append(mse1)
            mse_list2.append(mse2)
        #except:
        #    print(path[i] + file)
    mses1.append(mse_list1)
    mses2.append(mse_list2)

mses1 = [np.mean(mse) for mse in mses1]
mses2 = [np.mean(mse) for mse in mses2]

results = pd.DataFrame([mses1, mses2], columns=names, index=['MSE1', 'MSE2']).T

display(results)
#results.to_csv('mse_phase_damping.csv')
# Out:
# 100%|███████████████████████████████████████████████████████| 120/120 [00:56<00:00,  2.13it/s]
#                 MSE1      MSE2
# PD_0_25     0.000033  0.000176
# PD_0_35     0.000076  0.000234
# PD_0_45     0.000090  0.000295
# PD_0_55     0.000111  0.000340
# PD_0_65     0.000104  0.000311
# ...              ...       ...
# PD_003_215  0.000286  0.000837
# PD_003_300  0.000463  0.001014
# PD_003_500  0.000689  0.001160
# PD_003_700  0.000810  0.001219
# PD_003_900  0.000925  0.001283
#
# [120 rows x 2 columns]

# %%
from matplotlib.patches import Rectangle
from mpl_toolkits.axes_grid1 import make_axes_locatable

x = [25,35,45,55,65,75,85,95,105,115,125,135,145,155,165,175,185,195,205,300,500,700,900]
colors = ['lightskyblue', 'lightcoral', 'turquoise', 'black', 'gold', 'orange', 'lightgreen', 'mediumpurple']

#LIH '0','0001','0005','001', '003'
mses_PD_0001 = results['MSE1'][['PD_0001_'+ str(n) for n in x]]
mses_PD_0005 = results['MSE1'][['PD_0005_'+ str(n) for n in x]]
mses_PD_003 = results['MSE1'][['PD_003_'+ str(n) for n in x]]
mses_PD_001 = results['MSE1'][['PD_001_'+ str(n) for n in x]]
mses_PD_0 = results['MSE1'][['PD_0_'+ str(n) for n in x]]

fig, (ax1) = plt.subplots(1, 1,figsize = (15,10))

ax1.plot(x, mses_PD_0001, marker='o', color = colors[0], label ='PD 0.0001')
ax1.plot(x, mses_PD_0005, marker='o', color = colors[2], label ='PD 0.0005')
ax1.plot(x, mses_PD_003, marker='o', color = colors[1], label ='PD 0.003')
ax1.plot(x, mses_PD_001, marker='o', color = colors[4], label ='PD 0.001')
ax1.plot(x, mses_PD_0, marker='o', color = colors[5], label ='PD 0')


ax1.set_yscale('log')
ax1.set_xscale('linear')
ax1.set_xlim((20,205))

ax1.set_xlabel('Number of Gates',fontsize=14)
ax1.set_ylabel('Mean squared error',fontsize=14)
ax1.legend()

divider = make_axes_locatable(ax1)
ax2 = divider.append_axes("right", size=3, pad=0, sharey=ax1)
ax2.set_xscale('log')
ax2.set_xlim((205,1000))
ax2.spines['left'].set_visible(False)
ax2.yaxis.set_visible(False)
ax2.set_xticks([300,500,700,900], ['300','500','700', '900'], minor=False)
plt.minorticks_off()

ax2.plot(x, mses_PD_0001, marker='o', color = colors[0], label ='PD 0.0001')
ax2.plot(x, mses_PD_0005, marker='o', color = colors[2], label ='PD 0.0005')
ax2.plot(x, mses_PD_003, marker='o', color = colors[1], label ='PD 0.003')
ax2.plot(x, mses_PD_001, marker='o', color = colors[4], label ='PD 0.001')
ax2.plot(x, mses_PD_0, marker='o', color = colors[5], label ='PD 0')

plt.show()

# %% [markdown]
# ### Fidelity

# %%
path = []
files = []
names = []
for noise in ['0001','0005','001', '003']:
    for gates in ['25','35','45','55','65','75','85','95','105','115','125','135','145',
                  '155','165','175','185','195','205','215', '300', '500', '700', '900' ]:
        path_name = '../results/partial_noise/G3/phase_damping/'+noise+'/'+gates+'/'
        files_names = [f for f in listdir(path_name) if isfile(join(path_name, f))]
        names.append('PD_'+ noise +'_'+gates)
        path.append(path_name)
        files.append(files_names)

# %%
fidelity = []
mse_obs = []
for i in tqdm(range(len(files))):
    file_list = files[i]
    fidelity_list = []  
    mse_obs_list = []
    for file in file_list:
        # Load results
        with open(path[i] + file, 'rb') as f:
            result = np.load(f, allow_pickle=True) 
        f = np.array(result.tolist()['fidelity_list'])
        mean_fidelity = np.mean(f)
        fidelity_list.append(mean_fidelity)

    fidelity.append(fidelity_list)
    
fidelity = [np.mean(f) for f in fidelity]
fidelity_results = pd.DataFrame([fidelity], columns=names, index=['fidelity']).T
#fidelity_results.to_csv('fidelity_phase_damping.csv')
# Out:
# 100%|████████████████████████████████████████████████████████| 96/96 [00:00<00:00, 165.40it/s]

# %%
from matplotlib.patches import Rectangle

x = [25,35,45,55,65,75,85,95,105,115,125,135,145,155,165,175,185,195,205,215,300,500, 700, 900 ]
colors = ['lightskyblue', 'lightcoral', 'turquoise', 'black', 'gold', 'orange', 'lightgreen', 'mediumpurple']

#LIH
fidelity_PD_0001 = fidelity_results['fidelity'][['PD_0001_'+ str(n) for n in x]]
fidelity_PD_0005 = fidelity_results['fidelity'][['PD_0005_'+ str(n) for n in x]]
fidelity_PD_001 = fidelity_results['fidelity'][['PD_001_'+ str(n) for n in x]]
fidelity_PD_003 = fidelity_results['fidelity'][['PD_003_'+ str(n) for n in x]]

fig, (ax1) = plt.subplots(1, 1,figsize = (15,10))

ax1.plot(x, fidelity_PD_0001, marker='o', color = colors[0], label ='PD 0.0001')
ax1.plot(x, fidelity_PD_0005, marker='o', color = colors[2], label ='PD 0.0005')
ax1.plot(x, fidelity_PD_001, marker='o', color = colors[4], label ='PD 0.001')
ax1.plot(x, fidelity_PD_003, marker='o', color = colors[1], label ='PD 0.003')
ax1.legend()
#ax1.set_yscale('log')
ax1.tick_params(axis='both',labelsize=15)
ax1.set_yticks([0.99,  0.97, 0.95, 0.93, 0.91, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3,0.2])

ax1.set_xlabel('Number of Gates',fontsize=18)
ax1.set_ylabel('Fidelity',fontsize=18)
ax1.set_xlim((20,205))
ax1.legend()
plt.title('Fidelity Phase damping', fontsize=20)

divider = make_axes_locatable(ax1)
ax2 = divider.append_axes("right", size=3, pad=0, sharey=ax1)
ax2.set_xscale('log')
ax2.set_xlim((205,1000))
ax2.spines['left'].set_visible(False)
ax2.yaxis.set_visible(False)
ax2.set_xticks([300,500,700,900], ['300','500','700', '900'], minor=False, fontsize=18)
#plt.setp(ax2.get_xticklabels(), visible=True)
plt.minorticks_off()
ax2.plot(x, fidelity_PD_0001, marker='o', color = colors[0], label ='PD 0.0001')
ax2.plot(x, fidelity_PD_0005, marker='o', color = colors[2], label ='PD 0.0005')
ax2.plot(x, fidelity_PD_001, marker='o', color = colors[4], label ='PD 0.001')
ax2.plot(x, fidelity_PD_003, marker='o', color = colors[1], label ='PD 0.003')


plt.show()

# %% [markdown]
# ## 4. Thermal Relaxation

# %%
from os import listdir
from os.path import isfile, join

path = []
files = []
names = []
for noise in ['0.0','2.7e-05','8e-05','0.00016', '0.0008']:
    for gates in ['25','35','45','55','65','75','85','95','105','115','125','135','145',
                  '155','165','175','185','195','205','215', '300', '500', '700', '900' ]:

        path_name = '../results/partial_noise/G3/thermal_relaxation/'+noise+'/'+gates+'/'
            
        files_names = [f for f in listdir(path_name) if isfile(join(path_name, f))]
        names.append('TR_'+ noise +'_'+gates)
        path.append(path_name)
        files.append(files_names)

display(files)
# Out:
# [['obs_LiH_none_0.0_0.0_G3_25_all_rand453463.npy',
#   'obs_LiH_none_0.0_0.0_G3_25_all_rand1788666.npy',
#   'obs_LiH_none_0.0_0.0_G3_25_all_rand5306449.npy',
#   'obs_LiH_none_0.0_0.0_G3_25_all_rand759308.npy',
#   'obs_LiH_none_0.0_0.0_G3_25_all_rand5815058.npy',
#   'obs_LiH_none_0.0_0.0_G3_25_all_rand8856396.npy',
#   'obs_LiH_none_0.0_0.0_G3_25_all_rand4365580.npy',
#   'obs_LiH_none_0.0_0.0_G3_25_all_rand9224861.npy',
#   'obs_LiH_none_0.0_0.0_G3_25_all_rand4877963.npy',
#   'obs_LiH_none_0.0_0.0_G3_25_all_rand8340077.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_35_all_rand4237010.npy',
#   'obs_LiH_none_0.0_0.0_G3_35_all_rand4897673.npy',
#   'obs_LiH_none_0.0_0.0_G3_35_all_rand8023104.npy',
#   'obs_LiH_none_0.0_0.0_G3_35_all_rand4524568.npy',
#   'obs_LiH_none_0.0_0.0_G3_35_all_rand24514.npy',
#   'obs_LiH_none_0.0_0.0_G3_35_all_rand8089874.npy',
#   'obs_LiH_none_0.0_0.0_G3_35_all_rand9607792.npy',
#   'obs_LiH_none_0.0_0.0_G3_35_all_rand954020.npy',
#   'obs_LiH_none_0.0_0.0_G3_35_all_rand8441246.npy',
#   'obs_LiH_none_0.0_0.0_G3_35_all_rand8799197.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_45_all_rand2993266.npy',
#   'obs_LiH_none_0.0_0.0_G3_45_all_rand3403164.npy',
#   'obs_LiH_none_0.0_0.0_G3_45_all_rand646634.npy',
#   'obs_LiH_none_0.0_0.0_G3_45_all_rand190869.npy',
#   'obs_LiH_none_0.0_0.0_G3_45_all_rand4982278.npy',
#   'obs_LiH_none_0.0_0.0_G3_45_all_rand102205.npy',
#   'obs_LiH_none_0.0_0.0_G3_45_all_rand6340487.npy',
#   'obs_LiH_none_0.0_0.0_G3_45_all_rand270285.npy',
#   'obs_LiH_none_0.0_0.0_G3_45_all_rand7682010.npy',
#   'obs_LiH_none_0.0_0.0_G3_45_all_rand7999478.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_55_all_rand6932213.npy',
#   'obs_LiH_none_0.0_0.0_G3_55_all_rand5527419.npy',
#   'obs_LiH_none_0.0_0.0_G3_55_all_rand3593455.npy',
#   'obs_LiH_none_0.0_0.0_G3_55_all_rand5547165.npy',
#   'obs_LiH_none_0.0_0.0_G3_55_all_rand653353.npy',
#   'obs_LiH_none_0.0_0.0_G3_55_all_rand5285446.npy',
#   'obs_LiH_none_0.0_0.0_G3_55_all_rand7599225.npy',
#   'obs_LiH_none_0.0_0.0_G3_55_all_rand6990408.npy',
#   'obs_LiH_none_0.0_0.0_G3_55_all_rand9083680.npy',
#   'obs_LiH_none_0.0_0.0_G3_55_all_rand8187633.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_65_all_rand9592146.npy',
#   'obs_LiH_none_0.0_0.0_G3_65_all_rand5934265.npy',
#   'obs_LiH_none_0.0_0.0_G3_65_all_rand7059059.npy',
#   'obs_LiH_none_0.0_0.0_G3_65_all_rand7440489.npy',
#   'obs_LiH_none_0.0_0.0_G3_65_all_rand4133789.npy',
#   'obs_LiH_none_0.0_0.0_G3_65_all_rand9956117.npy',
#   'obs_LiH_none_0.0_0.0_G3_65_all_rand573986.npy',
#   'obs_LiH_none_0.0_0.0_G3_65_all_rand9508729.npy',
#   'obs_LiH_none_0.0_0.0_G3_65_all_rand5281793.npy',
#   'obs_LiH_none_0.0_0.0_G3_65_all_rand9813651.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_75_all_rand1358453.npy',
#   'obs_LiH_none_0.0_0.0_G3_75_all_rand4064200.npy',
#   'obs_LiH_none_0.0_0.0_G3_75_all_rand1607970.npy',
#   'obs_LiH_none_0.0_0.0_G3_75_all_rand9853774.npy',
#   'obs_LiH_none_0.0_0.0_G3_75_all_rand8708591.npy',
#   'obs_LiH_none_0.0_0.0_G3_75_all_rand3535541.npy',
#   'obs_LiH_none_0.0_0.0_G3_75_all_rand6119472.npy',
#   'obs_LiH_none_0.0_0.0_G3_75_all_rand5635293.npy',
#   'obs_LiH_none_0.0_0.0_G3_75_all_rand4862216.npy',
#   'obs_LiH_none_0.0_0.0_G3_75_all_rand1390871.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_85_all_rand945901.npy',
#   'obs_LiH_none_0.0_0.0_G3_85_all_rand6119005.npy',
#   'obs_LiH_none_0.0_0.0_G3_85_all_rand1812882.npy',
#   'obs_LiH_none_0.0_0.0_G3_85_all_rand9896375.npy',
#   'obs_LiH_none_0.0_0.0_G3_85_all_rand8549839.npy',
#   'obs_LiH_none_0.0_0.0_G3_85_all_rand8590145.npy',
#   'obs_LiH_none_0.0_0.0_G3_85_all_rand9099208.npy',
#   'obs_LiH_none_0.0_0.0_G3_85_all_rand4132784.npy',
#   'obs_LiH_none_0.0_0.0_G3_85_all_rand2849259.npy',
#   'obs_LiH_none_0.0_0.0_G3_85_all_rand8406185.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_95_all_rand2804087.npy',
#   'obs_LiH_none_0.0_0.0_G3_95_all_rand5673282.npy',
#   'obs_LiH_none_0.0_0.0_G3_95_all_rand8204898.npy',
#   'obs_LiH_none_0.0_0.0_G3_95_all_rand8803798.npy',
#   'obs_LiH_none_0.0_0.0_G3_95_all_rand9993618.npy',
#   'obs_LiH_none_0.0_0.0_G3_95_all_rand3602074.npy',
#   'obs_LiH_none_0.0_0.0_G3_95_all_rand9175862.npy',
#   'obs_LiH_none_0.0_0.0_G3_95_all_rand4801175.npy',
#   'obs_LiH_none_0.0_0.0_G3_95_all_rand7789869.npy',
#   'obs_LiH_none_0.0_0.0_G3_95_all_rand4466542.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_105_all_rand7995579.npy',
#   'obs_LiH_none_0.0_0.0_G3_105_all_rand4419605.npy',
#   'obs_LiH_none_0.0_0.0_G3_105_all_rand1663883.npy',
#   'obs_LiH_none_0.0_0.0_G3_105_all_rand2696933.npy',
#   'obs_LiH_none_0.0_0.0_G3_105_all_rand1304805.npy',
#   'obs_LiH_none_0.0_0.0_G3_105_all_rand2657734.npy',
#   'obs_LiH_none_0.0_0.0_G3_105_all_rand6965120.npy',
#   'obs_LiH_none_0.0_0.0_G3_105_all_rand7574766.npy',
#   'obs_LiH_none_0.0_0.0_G3_105_all_rand6404147.npy',
#   'obs_LiH_none_0.0_0.0_G3_105_all_rand5655407.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_115_all_rand2669387.npy',
#   'obs_LiH_none_0.0_0.0_G3_115_all_rand7030318.npy',
#   'obs_LiH_none_0.0_0.0_G3_115_all_rand2918688.npy',
#   'obs_LiH_none_0.0_0.0_G3_115_all_rand4415310.npy',
#   'obs_LiH_none_0.0_0.0_G3_115_all_rand5330713.npy',
#   'obs_LiH_none_0.0_0.0_G3_115_all_rand8490528.npy',
#   'obs_LiH_none_0.0_0.0_G3_115_all_rand2301468.npy',
#   'obs_LiH_none_0.0_0.0_G3_115_all_rand7775131.npy',
#   'obs_LiH_none_0.0_0.0_G3_115_all_rand7795645.npy',
#   'obs_LiH_none_0.0_0.0_G3_115_all_rand9603910.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_125_all_rand7064386.npy',
#   'obs_LiH_none_0.0_0.0_G3_125_all_rand439942.npy',
#   'obs_LiH_none_0.0_0.0_G3_125_all_rand2022379.npy',
#   'obs_LiH_none_0.0_0.0_G3_125_all_rand3037532.npy',
#   'obs_LiH_none_0.0_0.0_G3_125_all_rand2395397.npy',
#   'obs_LiH_none_0.0_0.0_G3_125_all_rand6021878.npy',
#   'obs_LiH_none_0.0_0.0_G3_125_all_rand1766660.npy',
#   'obs_LiH_none_0.0_0.0_G3_125_all_rand778561.npy',
#   'obs_LiH_none_0.0_0.0_G3_125_all_rand5719458.npy',
#   'obs_LiH_none_0.0_0.0_G3_125_all_rand9118019.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_135_all_rand2943745.npy',
#   'obs_LiH_none_0.0_0.0_G3_135_all_rand7062330.npy',
#   'obs_LiH_none_0.0_0.0_G3_135_all_rand1578825.npy',
#   'obs_LiH_none_0.0_0.0_G3_135_all_rand9864346.npy',
#   'obs_LiH_none_0.0_0.0_G3_135_all_rand6782302.npy',
#   'obs_LiH_none_0.0_0.0_G3_135_all_rand7391435.npy',
#   'obs_LiH_none_0.0_0.0_G3_135_all_rand2665551.npy',
#   'obs_LiH_none_0.0_0.0_G3_135_all_rand5796580.npy',
#   'obs_LiH_none_0.0_0.0_G3_135_all_rand5528814.npy',
#   'obs_LiH_none_0.0_0.0_G3_135_all_rand1926124.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_145_all_rand6169207.npy',
#   'obs_LiH_none_0.0_0.0_G3_145_all_rand2634944.npy',
#   'obs_LiH_none_0.0_0.0_G3_145_all_rand8129552.npy',
#   'obs_LiH_none_0.0_0.0_G3_145_all_rand9069091.npy',
#   'obs_LiH_none_0.0_0.0_G3_145_all_rand7552142.npy',
#   'obs_LiH_none_0.0_0.0_G3_145_all_rand7646479.npy',
#   'obs_LiH_none_0.0_0.0_G3_145_all_rand9735820.npy',
#   'obs_LiH_none_0.0_0.0_G3_145_all_rand5377090.npy',
#   'obs_LiH_none_0.0_0.0_G3_145_all_rand7051153.npy',
#   'obs_LiH_none_0.0_0.0_G3_145_all_rand2903862.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_155_all_rand7979918.npy',
#   'obs_LiH_none_0.0_0.0_G3_155_all_rand9998544.npy',
#   'obs_LiH_none_0.0_0.0_G3_155_all_rand9911385.npy',
#   'obs_LiH_none_0.0_0.0_G3_155_all_rand2164305.npy',
#   'obs_LiH_none_0.0_0.0_G3_155_all_rand9356418.npy',
#   'obs_LiH_none_0.0_0.0_G3_155_all_rand5779952.npy',
#   'obs_LiH_none_0.0_0.0_G3_155_all_rand6848918.npy',
#   'obs_LiH_none_0.0_0.0_G3_155_all_rand9250590.npy',
#   'obs_LiH_none_0.0_0.0_G3_155_all_rand5983330.npy',
#   'obs_LiH_none_0.0_0.0_G3_155_all_rand4940063.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_165_all_rand4257170.npy',
#   'obs_LiH_none_0.0_0.0_G3_165_all_rand2278452.npy',
#   'obs_LiH_none_0.0_0.0_G3_165_all_rand7184470.npy',
#   'obs_LiH_none_0.0_0.0_G3_165_all_rand3567799.npy',
#   'obs_LiH_none_0.0_0.0_G3_165_all_rand8874145.npy',
#   'obs_LiH_none_0.0_0.0_G3_165_all_rand3423313.npy',
#   'obs_LiH_none_0.0_0.0_G3_165_all_rand7127107.npy',
#   'obs_LiH_none_0.0_0.0_G3_165_all_rand4261509.npy',
#   'obs_LiH_none_0.0_0.0_G3_165_all_rand6604559.npy',
#   'obs_LiH_none_0.0_0.0_G3_165_all_rand284413.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_175_all_rand7250052.npy',
#   'obs_LiH_none_0.0_0.0_G3_175_all_rand211238.npy',
#   'obs_LiH_none_0.0_0.0_G3_175_all_rand6717463.npy',
#   'obs_LiH_none_0.0_0.0_G3_175_all_rand5065948.npy',
#   'obs_LiH_none_0.0_0.0_G3_175_all_rand2011299.npy',
#   'obs_LiH_none_0.0_0.0_G3_175_all_rand5603227.npy',
#   'obs_LiH_none_0.0_0.0_G3_175_all_rand3878267.npy',
#   'obs_LiH_none_0.0_0.0_G3_175_all_rand1929709.npy',
#   'obs_LiH_none_0.0_0.0_G3_175_all_rand9224433.npy',
#   'obs_LiH_none_0.0_0.0_G3_175_all_rand8646008.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_185_all_rand8930244.npy',
#   'obs_LiH_none_0.0_0.0_G3_185_all_rand8308480.npy',
#   'obs_LiH_none_0.0_0.0_G3_185_all_rand8610928.npy',
#   'obs_LiH_none_0.0_0.0_G3_185_all_rand5632378.npy',
#   'obs_LiH_none_0.0_0.0_G3_185_all_rand2958832.npy',
#   'obs_LiH_none_0.0_0.0_G3_185_all_rand5140236.npy',
#   'obs_LiH_none_0.0_0.0_G3_185_all_rand1476562.npy',
#   'obs_LiH_none_0.0_0.0_G3_185_all_rand695513.npy',
#   'obs_LiH_none_0.0_0.0_G3_185_all_rand7272620.npy',
#   'obs_LiH_none_0.0_0.0_G3_185_all_rand3671948.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_195_all_rand4746109.npy',
#   'obs_LiH_none_0.0_0.0_G3_195_all_rand9494592.npy',
#   'obs_LiH_none_0.0_0.0_G3_195_all_rand4478280.npy',
#   'obs_LiH_none_0.0_0.0_G3_195_all_rand2710422.npy',
#   'obs_LiH_none_0.0_0.0_G3_195_all_rand3133954.npy',
#   'obs_LiH_none_0.0_0.0_G3_195_all_rand5932733.npy',
#   'obs_LiH_none_0.0_0.0_G3_195_all_rand1300663.npy',
#   'obs_LiH_none_0.0_0.0_G3_195_all_rand499174.npy',
#   'obs_LiH_none_0.0_0.0_G3_195_all_rand8496289.npy',
#   'obs_LiH_none_0.0_0.0_G3_195_all_rand2101160.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_205_all_rand5423753.npy',
#   'obs_LiH_none_0.0_0.0_G3_205_all_rand1459487.npy',
#   'obs_LiH_none_0.0_0.0_G3_205_all_rand3661477.npy',
#   'obs_LiH_none_0.0_0.0_G3_205_all_rand6135858.npy',
#   'obs_LiH_none_0.0_0.0_G3_205_all_rand9644076.npy',
#   'obs_LiH_none_0.0_0.0_G3_205_all_rand3095151.npy',
#   'obs_LiH_none_0.0_0.0_G3_205_all_rand5284665.npy',
#   'obs_LiH_none_0.0_0.0_G3_205_all_rand1826955.npy',
#   'obs_LiH_none_0.0_0.0_G3_205_all_rand7525346.npy',
#   'obs_LiH_none_0.0_0.0_G3_205_all_rand1365832.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_215_all_rand2861844.npy',
#   'obs_LiH_none_0.0_0.0_G3_215_all_rand5177651.npy',
#   'obs_LiH_none_0.0_0.0_G3_215_all_rand6999992.npy',
#   'obs_LiH_none_0.0_0.0_G3_215_all_rand2994338.npy',
#   'obs_LiH_none_0.0_0.0_G3_215_all_rand5721907.npy',
#   'obs_LiH_none_0.0_0.0_G3_215_all_rand9412531.npy',
#   'obs_LiH_none_0.0_0.0_G3_215_all_rand227326.npy',
#   'obs_LiH_none_0.0_0.0_G3_215_all_rand3068379.npy',
#   'obs_LiH_none_0.0_0.0_G3_215_all_rand7357682.npy',
#   'obs_LiH_none_0.0_0.0_G3_215_all_rand6374515.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_300_all_rand297074.npy',
#   'obs_LiH_none_0.0_0.0_G3_300_all_rand2643416.npy',
#   'obs_LiH_none_0.0_0.0_G3_300_all_rand561039.npy',
#   'obs_LiH_none_0.0_0.0_G3_300_all_rand5641091.npy',
#   'obs_LiH_none_0.0_0.0_G3_300_all_rand2632217.npy',
#   'obs_LiH_none_0.0_0.0_G3_300_all_rand1437898.npy',
#   'obs_LiH_none_0.0_0.0_G3_300_all_rand7454583.npy',
#   'obs_LiH_none_0.0_0.0_G3_300_all_rand4808457.npy',
#   'obs_LiH_none_0.0_0.0_G3_300_all_rand5523062.npy',
#   'obs_LiH_none_0.0_0.0_G3_300_all_rand9733423.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_500_all_rand8000343.npy',
#   'obs_LiH_none_0.0_0.0_G3_500_all_rand4070985.npy',
#   'obs_LiH_none_0.0_0.0_G3_500_all_rand2612531.npy',
#   'obs_LiH_none_0.0_0.0_G3_500_all_rand739857.npy',
#   'obs_LiH_none_0.0_0.0_G3_500_all_rand7340135.npy',
#   'obs_LiH_none_0.0_0.0_G3_500_all_rand8220970.npy',
#   'obs_LiH_none_0.0_0.0_G3_500_all_rand1832486.npy',
#   'obs_LiH_none_0.0_0.0_G3_500_all_rand943082.npy',
#   'obs_LiH_none_0.0_0.0_G3_500_all_rand6768413.npy',
#   'obs_LiH_none_0.0_0.0_G3_500_all_rand6943871.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_700_all_rand8217123.npy',
#   'obs_LiH_none_0.0_0.0_G3_700_all_rand3821209.npy',
#   'obs_LiH_none_0.0_0.0_G3_700_all_rand1667972.npy',
#   'obs_LiH_none_0.0_0.0_G3_700_all_rand1499942.npy',
#   'obs_LiH_none_0.0_0.0_G3_700_all_rand336241.npy',
#   'obs_LiH_none_0.0_0.0_G3_700_all_rand6380151.npy',
#   'obs_LiH_none_0.0_0.0_G3_700_all_rand3695078.npy',
#   'obs_LiH_none_0.0_0.0_G3_700_all_rand4854499.npy',
#   'obs_LiH_none_0.0_0.0_G3_700_all_rand2145333.npy',
#   'obs_LiH_none_0.0_0.0_G3_700_all_rand231742.npy'],
#  ['obs_LiH_none_0.0_0.0_G3_900_all_rand8590911.npy',
#   'obs_LiH_none_0.0_0.0_G3_900_all_rand6553412.npy',
#   'obs_LiH_none_0.0_0.0_G3_900_all_rand7789450.npy',
#   'obs_LiH_none_0.0_0.0_G3_900_all_rand532995.npy',
#   'obs_LiH_none_0.0_0.0_G3_900_all_rand7694412.npy',
#   'obs_LiH_none_0.0_0.0_G3_900_all_rand4419277.npy',
#   'obs_LiH_none_0.0_0.0_G3_900_all_rand4953829.npy',
#   'obs_LiH_none_0.0_0.0_G3_900_all_rand4385873.npy',
#   'obs_LiH_none_0.0_0.0_G3_900_all_rand3856405.npy',
#   'obs_LiH_none_0.0_0.0_G3_900_all_rand7624780.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_25_all_rand3971897.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_25_all_rand4327987.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_25_all_rand5302194.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_35_all_rand4962794.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_35_all_rand3126116.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_35_all_rand9204618.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_45_all_rand1149636.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_45_all_rand3107833.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_45_all_rand9824600.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_55_all_rand7743765.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_55_all_rand4857316.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_55_all_rand7294188.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_65_all_rand9741399.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_65_all_rand7940412.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_65_all_rand8359994.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_75_all_rand429188.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_75_all_rand7540664.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_75_all_rand2760066.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_85_all_rand9777707.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_85_all_rand5666337.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_85_all_rand5505512.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_95_all_rand1091785.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_95_all_rand1676025.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_95_all_rand451887.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_105_all_rand2925489.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_105_all_rand1109775.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_105_all_rand8910828.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_115_all_rand2752956.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_115_all_rand9333708.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_115_all_rand3658896.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_125_all_rand3802497.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_125_all_rand8124728.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_125_all_rand8743942.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_135_all_rand1961208.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_135_all_rand2095874.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_135_all_rand2463267.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_145_all_rand8407517.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_145_all_rand4590070.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_145_all_rand3492534.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_155_all_rand4505977.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_155_all_rand9740621.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_155_all_rand3043963.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_165_all_rand8611244.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_165_all_rand7893368.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_165_all_rand9497955.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_175_all_rand4373806.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_175_all_rand7849309.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_175_all_rand9219444.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_185_all_rand1577703.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_185_all_rand2326750.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_185_all_rand808356.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_195_all_rand3263144.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_195_all_rand5662920.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_195_all_rand117070.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_205_all_rand4462308.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_205_all_rand1267478.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_205_all_rand6451754.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_215_all_rand9389726.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_215_all_rand873869.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_215_all_rand2331951.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_300_all_rand4471591.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_300_all_rand9013328.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_300_all_rand7235027.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_500_all_rand7377913.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_500_all_rand1202355.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_500_all_rand2918401.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_700_all_rand1144565.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_700_all_rand4251111.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_700_all_rand9345018.npy'],
#  ['obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_900_all_rand3533535.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_900_all_rand2464558.npy',
#   'obs_LiH_thermal_relaxation_2.7e-05_3.8e-05_G3_900_all_rand4553649.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_25_all_rand3375749.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_25_all_rand5633031.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_25_all_rand4840864.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_35_all_rand5583022.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_35_all_rand4067281.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_35_all_rand667179.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_45_all_rand8765813.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_45_all_rand6972073.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_45_all_rand9458606.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_55_all_rand3254468.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_55_all_rand865042.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_55_all_rand7637214.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_65_all_rand2553506.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_65_all_rand5911556.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_65_all_rand2779255.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_75_all_rand3220450.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_75_all_rand7468208.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_75_all_rand9825182.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_85_all_rand2523394.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_85_all_rand8470517.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_85_all_rand5304781.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_95_all_rand5016546.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_95_all_rand7463181.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_95_all_rand8463779.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_105_all_rand2434849.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_105_all_rand4888758.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_105_all_rand2313895.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_115_all_rand7063619.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_115_all_rand12012.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_115_all_rand625051.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_125_all_rand8847862.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_125_all_rand5757836.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_125_all_rand5478375.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_135_all_rand74807.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_135_all_rand3968466.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_135_all_rand7477904.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_145_all_rand8776512.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_145_all_rand3494109.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_145_all_rand3433248.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_155_all_rand7605761.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_155_all_rand9725158.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_155_all_rand7661797.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_165_all_rand118636.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_165_all_rand6862215.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_165_all_rand3125647.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_175_all_rand5828346.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_175_all_rand6146632.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_175_all_rand2718408.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_185_all_rand3845816.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_185_all_rand2870221.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_185_all_rand8143115.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_195_all_rand6498014.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_195_all_rand9105035.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_195_all_rand1560126.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_205_all_rand6724192.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_205_all_rand3425930.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_205_all_rand8697945.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_215_all_rand6700523.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_215_all_rand2260168.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_215_all_rand1285743.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_300_all_rand4987954.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_300_all_rand4811394.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_300_all_rand848880.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_500_all_rand375939.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_500_all_rand669013.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_500_all_rand9788155.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_700_all_rand4721516.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_700_all_rand8081506.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_700_all_rand6451409.npy'],
#  ['obs_LiH_thermal_relaxation_8e-05_0.000112_G3_900_all_rand8173258.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_900_all_rand7807301.npy',
#   'obs_LiH_thermal_relaxation_8e-05_0.000112_G3_900_all_rand8236325.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_25_all_rand193420.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_25_all_rand1867865.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_25_all_rand9757423.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_35_all_rand3557417.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_35_all_rand4437504.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_35_all_rand499458.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_45_all_rand3143648.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_45_all_rand7239884.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_45_all_rand1989617.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_55_all_rand2767969.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_55_all_rand47193.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_55_all_rand5500679.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_65_all_rand6701724.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_65_all_rand3416863.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_65_all_rand3552690.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_75_all_rand6603680.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_75_all_rand2593210.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_75_all_rand5945755.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_85_all_rand2306626.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_85_all_rand9020352.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_85_all_rand3472019.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_95_all_rand3816381.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_95_all_rand8357080.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_95_all_rand4366418.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_105_all_rand6623248.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_105_all_rand9069552.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_105_all_rand9773561.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_115_all_rand127789.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_115_all_rand6468308.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_115_all_rand3912848.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_125_all_rand8273916.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_125_all_rand205947.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_125_all_rand5465190.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_135_all_rand5456198.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_135_all_rand6974886.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_135_all_rand1740726.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_145_all_rand9605776.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_145_all_rand7668894.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_145_all_rand5756592.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_155_all_rand3266527.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_155_all_rand8803885.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_155_all_rand6188452.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_165_all_rand9652007.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_165_all_rand4039304.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_165_all_rand8443483.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_175_all_rand2224614.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_175_all_rand2862722.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_175_all_rand3938582.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_185_all_rand9661209.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_185_all_rand6273299.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_185_all_rand8072804.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_195_all_rand4960261.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_195_all_rand114435.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_195_all_rand5078417.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_205_all_rand1231083.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_205_all_rand2593655.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_205_all_rand9262021.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_215_all_rand437796.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_215_all_rand9446591.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_215_all_rand5569131.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_300_all_rand4359136.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_300_all_rand2570727.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_300_all_rand4340075.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_500_all_rand6790230.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_500_all_rand8737640.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_500_all_rand761738.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_700_all_rand4275823.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_700_all_rand5229500.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_700_all_rand6444927.npy'],
#  ['obs_LiH_thermal_relaxation_0.00016_0.000224_G3_900_all_rand5022687.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_900_all_rand8735383.npy',
#   'obs_LiH_thermal_relaxation_0.00016_0.000224_G3_900_all_rand5732288.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_25_all_rand9298208.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_25_all_rand8442463.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_25_all_rand8079019.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_35_all_rand8280903.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_35_all_rand5087256.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_35_all_rand4741767.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_45_all_rand4238498.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_45_all_rand7124088.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_45_all_rand9194082.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_55_all_rand114173.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_55_all_rand8881795.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_55_all_rand5802585.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_65_all_rand7891551.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_65_all_rand6581034.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_65_all_rand388102.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_75_all_rand5188530.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_75_all_rand6132296.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_75_all_rand1818796.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_85_all_rand582757.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_85_all_rand2438310.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_85_all_rand5627744.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_95_all_rand25361.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_95_all_rand9497408.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_95_all_rand3680808.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_105_all_rand5718994.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_105_all_rand3483850.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_105_all_rand2992644.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_115_all_rand3008357.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_115_all_rand4825781.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_115_all_rand4777348.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_125_all_rand1636387.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_125_all_rand3123005.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_125_all_rand982607.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_135_all_rand7731678.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_135_all_rand4908097.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_135_all_rand3876100.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_145_all_rand7594868.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_145_all_rand3986398.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_145_all_rand9120191.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_155_all_rand7883912.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_155_all_rand8819610.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_155_all_rand8999345.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_165_all_rand3879683.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_165_all_rand9102527.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_165_all_rand88249.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_175_all_rand8629385.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_175_all_rand4711285.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_175_all_rand7987039.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_185_all_rand1384936.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_185_all_rand26433.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_185_all_rand2649440.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_195_all_rand6334791.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_195_all_rand8842340.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_195_all_rand9220460.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_205_all_rand1443796.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_205_all_rand9053034.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_205_all_rand4265600.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_215_all_rand5466543.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_215_all_rand7017342.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_215_all_rand9379754.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_300_all_rand9679182.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_300_all_rand4501787.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_300_all_rand7844004.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_500_all_rand9145910.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_500_all_rand7668702.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_500_all_rand6678276.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_700_all_rand6829171.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_700_all_rand5060083.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_700_all_rand3043558.npy'],
#  ['obs_LiH_thermal_relaxation_0.0008_0.00112_G3_900_all_rand8983170.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_900_all_rand440444.npy',
#   'obs_LiH_thermal_relaxation_0.0008_0.00112_G3_900_all_rand997673.npy']]

# %%
### Prediction errors

# %%
alpha = 1e-9
alpha2 = 1e-9
mses1 = []
mses2 = []
for i in tqdm(range(len(files))):
    file_list = files[i]
    mse_list1 = []  
    mse_list2 = [] 
    for file in file_list:
        #try:
            # Load results
            with open(path[i] + file, 'rb') as f:
                obs_res = np.load(f, allow_pickle=True) 
            try:
                non_zero_obs = [~np.isclose(obs_res[:,j],0).all() for j in range(obs_res.shape[1])]
            except:
                obs_res = obs_res.tolist()['observables']
                non_zero_obs = [~np.isclose(obs_res[:,j],0).all() for j in range(obs_res.shape[1])]
            if sum(non_zero_obs)>0:
                obs_res = obs_res[:,non_zero_obs]
            obs_res = obs_res[:, ~np.isnan(obs_res).any(axis=0)]
            # Separate train and test uniformly
            size = obs_res.shape[0]
            idx1 = int(0.2*size)
            idx2 = int(0.5*size)
            train_idx=list(range(idx1)) + list(range(idx2, size))
            X_train, y_train, bond_lengths_train = obs_res[train_idx], y[train_idx], bond_lengths[train_idx]
            X_test, y_test, bond_lengths_test = obs_res[idx1:idx2], y[idx1:idx2], bond_lengths[idx1:idx2]
            #X_train, X_test, y_train, y_test, bond_lengths_train, bond_lengths_test = train_test_split( 
            #        obs_res, y, bond_lengths, test_size=0.33, random_state=42)
            # Scale target
            scaler = MinMaxScaler()
            y_train_scaled = scaler.fit_transform(y_train)
            y_test_scaled = scaler.transform(y_test)
            # Fit linear model
            alpha_sel = alpha if i>24 else alpha2
            lm1 = Ridge(alpha=alpha_sel)
            lm1.fit(X_train, y_train_scaled[:,0])
            lm2 = Ridge(alpha=alpha_sel)
            lm2.fit(X_train, y_train_scaled[:,1])
            # Predict
            y_hat1 = lm1.predict(X_test)
            y_hat2 = lm2.predict(X_test)
            y_hat = np.vstack([y_hat1, y_hat2]).T
            y_hat = scaler.inverse_transform(y_hat)
            
            
            idx_rm = (y_hat[:,0]>0.09) | (y_hat[:,0]<0.0)
            y_hat_n = y_hat[~idx_rm,0]
            y_test_n = y_test[~idx_rm,0]
            
            idx_rm2 = (y_hat[:,1]>0.15) | (y_hat[:,1]<0.05)
            y_hat_n2 = y_hat[~idx_rm,1]
            y_test_n2 = y_test[~idx_rm,1]
            # MSE
            mse1 = np.mean(np.square(y_hat_n - y_test_n))
            mse2 = np.mean(np.square(y_hat_n2 - y_test_n2))
            mse_list1.append(mse1)
            mse_list2.append(mse2)
        #except:
        #    print(path[i] + file)
    mses1.append(mse_list1)
    mses2.append(mse_list2)

mses1 = [np.mean(mse) for mse in mses1]
mses2 = [np.mean(mse) for mse in mses2]

results = pd.DataFrame([mses1, mses2], columns=names, index=['MSE1', 'MSE2']).T

display(results)
results.to_csv('mse_thermal_relaxation.csv')
# Out:
# 100%|███████████████████████████████████████████████████████| 120/120 [00:01<00:00, 81.78it/s]
#                    MSE1      MSE2
# TR_0.0_25      0.000074  0.000232
# TR_0.0_35      0.000076  0.000153
# TR_0.0_45      0.000082  0.000300
# TR_0.0_55      0.000111  0.000265
# TR_0.0_65      0.000100  0.000318
# ...                 ...       ...
# TR_0.0008_215  0.000001  0.000002
# TR_0.0008_300  0.000003  0.000001
# TR_0.0008_500  0.000005  0.000002
# TR_0.0008_700  0.000008  0.000002
# TR_0.0008_900  0.000006  0.000001
#
# [120 rows x 2 columns]

# %%
from matplotlib.patches import Rectangle
from mpl_toolkits.axes_grid1 import make_axes_locatable

x = [25,35,45,55,65,75,85,95,105,115,125,135,145,155,165,175,185,195,205,300,500,700,900]
colors = ['lightskyblue', 'lightcoral', 'turquoise', 'black', 'gold', 'orange', 'lightgreen', 'mediumpurple']

mses_TR_800eneg6 = results['MSE1'][['TR_0.0008_'+ str(n) for n in x]]
mses_TR_160eneg6 = results['MSE1'][['TR_0.00016_'+ str(n) for n in x]]
mses_TR_80eneg6 = results['MSE1'][['TR_8e-05_'+ str(n) for n in x]]
mses_TR_27eneg6 = results['MSE1'][['TR_2.7e-05_'+ str(n) for n in x]]
mses_TR_0 = results['MSE1'][['TR_0.0_'+ str(n) for n in x]]

fig, (ax1) = plt.subplots(1, 1,figsize = (15,10))

ax1.plot(x, mses_TR_800eneg6, marker='o', color = colors[0], label ='T₁=800e-6')
ax1.plot(x, mses_TR_160eneg6, marker='o', color = colors[2], label ='T₁=160e-6')
ax1.plot(x, mses_TR_80eneg6, marker='o', color = colors[1], label ='T₁=80e-6')
ax1.plot(x, mses_TR_27eneg6, marker='o', color = colors[4], label ='T₁=27e-6')
ax1.plot(x, mses_TR_0, marker='o', color = 'black', label ='Noiseless')


ax1.set_yscale('log')
ax1.set_xscale('linear')
ax1.set_xlim((20,205))

ax1.set_xlabel('Number of Gates',fontsize=24)
ax1.set_ylabel('Mean squared error',fontsize=24)


divider = make_axes_locatable(ax1)
ax2 = divider.append_axes("right", size=3, pad=0, sharey=ax1)
ax2.set_xscale('log')
ax2.set_xlim((205,1000))
ax2.spines['left'].set_visible(False)
ax2.yaxis.set_visible(False)
ax2.set_xticks([300,500,700,900], ['300','500','700', '900'], minor=False)
plt.minorticks_off()

ax1.legend(fontsize=20)  # Increase legend font size
ax1.tick_params(axis='both', which='major', labelsize=15)  # Axis tick labels
ax1.tick_params(axis='both', which='minor', labelsize=15)  # Minor ticks if needed
ax2.tick_params(axis='x', which='major', labelsize=15)

ax2.plot(x, mses_TR_800eneg6, marker='o', color = colors[0], label ='T₁=800e-6')
ax2.plot(x, mses_TR_160eneg6, marker='o', color = colors[2], label ='T₁=160e-6')
ax2.plot(x, mses_TR_80eneg6, marker='o', color = colors[1], label ='T₁=80e-6')
ax2.plot(x, mses_TR_27eneg6, marker='o', color = colors[4], label ='T₁=27e-6')
ax2.plot(x, mses_TR_0, marker='o', color = 'black', label ='Noiseless')

fig.tight_layout()
plt.savefig('thermal_mse.png', format='png')
plt.show()

# %%
### Fidelity

# %%
path = []
files = []
names = []
for noise in ['0.0','2.7e-05','8e-05','0.00016', '0.0008']:
    for gates in ['25','35','45','55','65','75','85','95','105','115','125','135','145',
                  '155','165','175','185','195','205','215', '300', '500', '700', '900' ]:
        path_name = '../results/partial_noise/G3/thermal_relaxation/'+noise+'/'+gates+'/'
            
        files_names = [f for f in listdir(path_name) if isfile(join(path_name, f))]
        names.append('TR_'+ noise +'_'+gates)
        path.append(path_name)
        files.append(files_names)

# %%
fidelity = []
mse_obs = []
for i in tqdm(range(len(files))):
    file_list = files[i]
    fidelity_list = []  
    mse_obs_list = []
    for file in file_list:
        # Load results
        with open(path[i] + file, 'rb') as f:
            result = np.load(f, allow_pickle=True) 
        f = np.array(result.tolist()['fidelity_list'])
        mean_fidelity = np.mean(f)
        fidelity_list.append(mean_fidelity)

    fidelity.append(fidelity_list)
    
fidelity = [np.mean(f) for f in fidelity]
fidelity_results = pd.DataFrame([fidelity], columns=names, index=['fidelity']).T

display(fidelity_results)
fidelity_results.to_csv('fidelity_thermal_relaxation.csv')
# Out:
# 100%|█████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2131.87it/s]
#                fidelity
# TR_0.0_25      1.000000
# TR_0.0_35      1.000000
# TR_0.0_45      1.000000
# TR_0.0_55      1.000000
# TR_0.0_65      1.000000
# ...                 ...
# TR_0.0008_215  0.396134
# TR_0.0008_300  0.275108
# TR_0.0008_500  0.121006
# TR_0.0008_700  0.049392
# TR_0.0008_900  0.018914
#
# [120 rows x 1 columns]

# %%
from matplotlib.patches import Rectangle

x = [25,35,45,55,65,75,85,95,105,115,125,135,145,155,165,175,185,195,205,215,300,500, 700, 900 ]
colors = ['lightskyblue', 'lightcoral', 'turquoise', 'black', 'gold', 'orange', 'lightgreen', 'mediumpurple']

fidelity_TR_800eneg6 = fidelity_results['fidelity'][['TR_0.0008_'+ str(n) for n in x]]
fidelity_TR_160eneg6 = fidelity_results['fidelity'][['TR_0.00016_'+ str(n) for n in x]]
fidelity_TR_80eneg6 = fidelity_results['fidelity'][['TR_8e-05_'+ str(n) for n in x]]
fidelity_TR_27eneg6 = fidelity_results['fidelity'][['TR_2.7e-05_'+ str(n) for n in x]]
# fidelity_TR_0 = fidelity_results['fidelity'][['TR_0.0_'+ str(n) for n in x]]

fig, (ax1) = plt.subplots(1, 1,figsize = (15,10))

ax1.plot(x, fidelity_TR_800eneg6, marker='o', color = colors[0], label ='T₁=800e-6')
ax1.plot(x, fidelity_TR_160eneg6, marker='o', color = colors[2], label ='T₁=160e-6')
ax1.plot(x, fidelity_TR_80eneg6, marker='o', color = colors[1], label ='T₁=80e-6')
ax1.plot(x, fidelity_TR_27eneg6, marker='o', color = colors[4], label ='T₁=27e-6')
# ax1.plot(x, fidelity_TR_0, marker='o', color = 'black', label ='Noiseless')

#ax1.set_yscale('log')
ax1.tick_params(axis='both',labelsize=15)
ax1.set_yticks([0.99,  0.97, 0.95, 0.93, 0.91, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3,0.2])

ax1.set_xlabel('Number of Gates',fontsize=24)
ax1.set_ylabel('Fidelity',fontsize=24)
ax1.set_xlim((20,205))

plt.title('Fidelity Thermal relexation', fontsize=20)

divider = make_axes_locatable(ax1)
ax2 = divider.append_axes("right", size=3, pad=0, sharey=ax1)
ax2.set_xscale('log')
ax2.set_xlim((205,1000))
ax2.spines['left'].set_visible(False)
ax2.yaxis.set_visible(False)
ax2.set_xticks([300,500,700,900], ['300','500','700', '900'], minor=False, fontsize=18)
#plt.setp(ax2.get_xticklabels(), visible=True)
plt.minorticks_off()
ax2.plot(x, fidelity_TR_800eneg6, marker='o', color = colors[0], label ='T₁=800e-6')
ax2.plot(x, fidelity_TR_160eneg6, marker='o', color = colors[2], label ='T₁=160e-6')
ax2.plot(x, fidelity_TR_80eneg6, marker='o', color = colors[1], label ='T₁=80e-6')
ax2.plot(x, fidelity_TR_27eneg6, marker='o', color = colors[4], label ='T₁=27e-6')
# ax2.plot(x, fidelity_TR_0, marker='o', color = 'black', label ='Noiseless')

ax1.legend(fontsize=20)  # Increase legend font size
ax1.tick_params(axis='both', which='major', labelsize=15)  # Axis tick labels
ax1.tick_params(axis='both', which='minor', labelsize=15)  # Minor ticks if needed
ax2.tick_params(axis='x', which='major', labelsize=15)

fig.tight_layout()
plt.savefig('thermal_fidelity.png', format='png')
plt.show()

# %% [markdown]
# ## 5. Distribution in the Pauli space
#
# We study the distribution of the noisy quantum states $\rho$ in the Pauli space for each of the three noise models. We compare it with randomly filling the space. For simplicity and better visualization, we use a toy model of just 2 qubits.

# %%
from qiskit_aer.noise import NoiseModel
import qiskit_aer.noise as noise
class QuantumCircQiskit:
    def __init__(self, gates_name, num_gates=50,nqbits=8,observables_type = 'fidelity',
                 err_type='depolarizing', err_p1=0.001, err_p2=0.01, err_idle=0.00001, t1=50e-6, 
                        t2=70e-6, gate_time_1q=57e-9, gate_time_2q=533e-9, t_idle_time=1e-6, excited_state_population=0.0):
        
        self.num_gates = num_gates
        self.gates_name = gates_name
        self.observables_type = observables_type
        self.gates_set = []
        self.qubits_set = []
        self.nqbits=nqbits
        self.coupling_map=None
        self.err_type = err_type
        if err_type is not None:
            noise_model, basis_gates = self.get_noise_model(err_type=err_type, p1=err_p1, p2=err_p2, p_idle=err_idle)
        else:
            noise_model, basis_gates = None, None
            
        self.noise_model = noise_model
        self.basis_gates = basis_gates
        if self.gates_name=='G1':
            gates = ['CNOT', 'H', 'X']
        if self.gates_name=='G2':
            gates = ['CNOT', 'H', 'S']
        if self.gates_name=='G3':
            gates = ['CNOT', 'H', 'T']  
        
        qubit_idx = list(range(self.nqbits))
        # Store gates
        if self.gates_name in ['G1', 'G2', 'G3']:
            for i in range(self.num_gates):
                # Select random gate
                gate = random.sample(gates,1)[0] 
                self.gates_set.append(gate)
                if gate=='CNOT':
                    # Select qubit 1 and 2 (different qubits)
                    qbit1 = random.sample(qubit_idx,1)[0]
                    qubit_idx2 = qubit_idx.copy()
                    qubit_idx2.remove(qbit1)
                    qbit2 = random.sample(qubit_idx2,1)[0]
                    self.qubits_set.append([qbit1, qbit2])
                else:
                    # Select qubit
                    qbit = random.sample(qubit_idx,1)[0]
                    self.qubits_set.append([qbit])

                
    def initialization(self, initial_state):
        # 1. INITIALIZATION
        # Define initial state
        initial_state = initial_state.round(6)
        initial_state/=np.sqrt(np.sum(initial_state**2))

        # Define qiskit circuit to initialize quantum state
        self.nqbits = int(np.log2(initial_state.shape[0]))
        qc = QuantumCircuit(self.nqbits)
        qc.initialize(initial_state, list(range(self.nqbits)))
        return qc

    def apply_G_gates(self, qc):
        # Apply random gates to random qubits
        for i in range(self.num_gates):
            # Select random gate
            # Select random gate
            gate = self.gates_set[i]
            if gate=='CNOT': # For 2-qubit gates
                # Select qubit 1 and 2 (different qubits)
                qbit1, qbit2 = self.qubits_set[i]
                # Apply gate to qubits
                qc.cx(qbit1, qbit2) 
                # Appply identity operator to all idle qubits if we use an ide noise model
                if self.err_type=='depolarizing_idle' or self.err_type=='amplitude_damping_idle' or self.err_type=='phase_damping_idle':
                    qubit_idx = list(range(self.nqbits))
                    qubit_idx.remove(qbit1)
                    qubit_idx.remove(qbit2)
                    # Apply identity gates to other gates
                    for qbit in qubit_idx:
                        qc.id(qbit)
            else: # For 1-qubit gates
                # Select qubit
                qbit = self.qubits_set[i][0]
                if gate=='X':# Apply gate
                    qc.x(qbit) 
                if gate=='S':
                    qc.s(qbit) 
                if gate=='H':
                    qc.h(qbit) 
                if gate=='T':
                    qc.t(qbit) 
                # Appply identity operator to all idle qubits if we use an ide noise model
                if self.err_type=='depolarizing_idle' or self.err_type=='amplitude_damping_idle' or self.err_type=='phase_damping_idle':
                    qubit_idx = list(range(self.nqbits))
                    qubit_idx.remove(qbit)
                    # Apply identity gates to other gates
                    for qbit in qubit_idx:
                        qc.id(qbit)
                
    def gate_unitary(self, i):
        qc = QuantumCircuit(self.nqbits)
        # Apply random gates to random qubits
        gate = self.gates_set[i]
        if gate=='CNOT': # For 2-qubit gates
            # Select qubit 1 and 2 (different qubits)
            qbit1, qbit2 = self.qubits_set[i]
            # Apply gate to qubits
            qc.cx(qbit1, qbit2) 
            # Appply identity operator to all idle qubits if we use an ide noise model
            if self.err_type=='depolarizing_idle' or self.err_type=='amplitude_damping_idle' or self.err_type=='phase_damping_idle':
                qubit_idx = list(range(self.nqbits))
                qubit_idx.remove(qbit1)
                qubit_idx.remove(qbit2)
                # Apply identity gates to other gates
                for qbit in qubit_idx:
                    qc.id(qbit)
        else: # For 1-qubit gates
            # Select qubit
            qbit = self.qubits_set[i][0]
            if gate=='X':# Apply gate
                qc.x(qbit) 
            if gate=='S':
                qc.s(qbit) 
            if gate=='H':
                qc.h(qbit) 
            if gate=='T':
                qc.t(qbit) 
            # Appply identity operator to all idle qubits if we use an ide noise model
            if self.err_type=='depolarizing_idle' or self.err_type=='amplitude_damping_idle' or self.err_type=='phase_damping_idle':
                qubit_idx = list(range(self.nqbits))
                qubit_idx.remove(qbit)
                # Apply identity gates to other gates
                for qbit in qubit_idx:
                    qc.id(qbit)
        backend = Aer.get_backend('unitary_simulator')
        job = backend.run(transpile(qc, backend))
        U = np.array(job.result().get_unitary(qc))
        return U
                        
                

    def get_noise_model(self, err_type='depolarizing', p1=0.001, p2=0.01, p_idle=0.0001, t1=50e-6, 
                        t2=70e-6, gate_time_1q=57e-9, gate_time_2q=533e-9, t_idle_time=1e-6, excited_state_population=0.0):
        # Error probabilities: p1=1-qubit gate, p2=2-qubit gate
        if err_type=='depolarizing' or err_type=='depolarizing_idle':
            # Depolarizing quantum errors
            error_1 = noise.depolarizing_error(p1, 1)
            error_2 = noise.depolarizing_error(p2, 2)
            error_idle = noise.depolarizing_error(p_idle, 1)
        elif err_type=='phase_damping' or err_type=='phase_damping_idle':
            # Depolarizing quantum errors
            error_1 = noise.phase_damping_error(p1, 1)
            error_2 = noise.phase_damping_error(p2, 2)
            error_2 = error_1.tensor(error_2)
            error_idle = noise.phase_damping_error(p_idle, 1)
        elif err_type=='amplitude_damping' or err_type=='amplitude_damping_idle':
            # Construct the error
            error_1 = noise.amplitude_damping_error(p1)
            error_2 = noise.amplitude_damping_error(p2)
            error_2 = error_1.tensor(error_2)
            error_idle = noise.amplitude_damping_error(p_idle, 1)

        elif err_type=='thermal_relaxation' or err_type=='thermal_relaxation_idle':
            # Validate T2 <= 2*T1 (physical constraint)
            if t2 > 2 * t1:
                raise ValueError(f'T2 ({t2}s) must be <= 2*T1 ({2*t1}s)')

            error_1 = noise.thermal_relaxation_error(
            t1=t1, t2=t2, time=gate_time_1q,
            excited_state_population=excited_state_population)

            # Two-qubit error: tensor two independent single-qubit errors
            # Each qubit in the cx experiences relaxation for gate_time_2q
            error_2_q0 = noise.thermal_relaxation_error(
                t1=t1, t2=t2, time=gate_time_2q,
                excited_state_population=excited_state_population)
            error_2_q1 = noise.thermal_relaxation_error(
                t1=t1, t2=t2, time=gate_time_2q,
                excited_state_population=excited_state_population)
            
            error_2 = error_2_q0.tensor(error_2_q1)

            # Idle error
            error_idle = noise.thermal_relaxation_error(
                t1=t1, t2=t2, time=t_idle_time,
                excited_state_population=excited_state_population
        )
        
        elif err_type=='fake':
            provider = FakeProvider()
            names = [ b.name() for b in provider.backends() if b.configuration().n_qubits >= self.nqbits]
            if len(names)==0:
                raise ValueError('Error type not supported')
            fake = provider.get_backend(names[7])
            # Get coupling map from backend
            coupling_map = fake.configuration().coupling_map
            cmap = [[self.nqbits-1,1]]
            for i,j in coupling_map:
                if i<nqbits and j<nqbits:
                    cmap.append([i,j]) 
            self.coupling_map = cmap
            noise_model = NoiseModel.from_backend(fake)
            basis_gates = noise_model.basis_gates
            return noise_model, basis_gates
        else:
            raise ValueError('Error type not supported', err_type)
        # Add errors to noise model
        noise_model = noise.NoiseModel()
        
        noise_model.add_all_qubit_quantum_error(error_1, ['x','h','ry','rz','u1', 'u2', 'u3'])
        noise_model.add_all_qubit_quantum_error(error_2, ['cx'])
        if err_type=='depolarizing_idle' or err_type=='amplitude_damping_idle' or err_type=='phase_damping_idle' or err_type=='thermal_relaxation_idle':
            noise_model.add_all_qubit_quantum_error(error_idle, ['id'])

        # Get basis gates from noise model
        basis_gates = noise_model.basis_gates
        return noise_model, basis_gates
        
    def get_observables(self):
        observables = []
        name_gate=''
        for i in range(self.nqbits):
            name_gate+= 'I' 
        for i in range(self.nqbits):
            # X
            op_nameX = name_gate[:i] + 'X' + name_gate[(i+1):]
            obs = PauliOp(Pauli(op_nameX))
            observables.append(obs)
            # Y
            op_nameY = name_gate[:i] + 'Y' + name_gate[(i+1):]
            obs = PauliOp(Pauli(op_nameY))
            observables.append(obs)
            # Z
            op_nameZ = name_gate[:i] + 'Z' + name_gate[(i+1):]
            obs = PauliOp(Pauli(op_nameZ))
            observables.append(obs)
        return observables

# %%
from qiskit_aer.library import SaveDensityMatrix 
from qiskit.quantum_info import DensityMatrix
from qiskit_aer import AerSimulator
def pauli_group_span(name_gate='G3', nqbits=2, num_samples=400, num_gates=20, err_type='depolarizing_idle', err_p1=0.00008, err_p2=0.00008, err_idle=0.0001, t1=488e-9, t2=683e-9):
    coefs_pauli_group = []
    coefs_pauli_group_noiseless = []
    paulis = pauli_basis(2)
    paulis_mat = [p.to_matrix() for p in paulis]
    for j in tqdm(range(num_samples)):
        # Define quantum circuit
        qc_tot = QuantumCircQiskit(name_gate, num_gates=num_gates,nqbits=nqbits,observables_type = 'all',
                                   err_type=err_type, err_p1=err_p1, err_p2=err_p2, err_idle=err_idle)
        qc = QuantumCircuit(nqbits)
        qc.h(0)
        qc.h(1)
        qc_tot.apply_G_gates(qc)

        # Obtain super operator from circuit with noise model
        qubits = [i for i in range(qc.num_qubits)]
        qc.append(SaveDensityMatrix(qc.num_qubits, label=f'rho'), qubits)
        if err_type is not None:
            backend = AerSimulator(method='density_matrix',noise_model=qc_tot.noise_model,basis_gates=qc_tot.basis_gates)
        else:
            backend = AerSimulator(method='density_matrix')
        qc_transpiled = transpile(qc, backend)
        result_noise = backend.run(qc_transpiled).result()
        density_matrix = np.array(result_noise.data()['rho'])
        coefs_noise = [np.trace(density_matrix @ p).real for p in paulis_mat]
        coefs_pauli_group.append(coefs_noise)
        # Noiseless simulation
        backend = AerSimulator(method='density_matrix')
        qc_transpiled = transpile(qc, backend)
        result = backend.run(qc_transpiled).result()
        density_matrix = np.array(result.data()['rho'])
        coefs = [np.trace(density_matrix @ p).real for p in paulis_mat]
        coefs_pauli_group_noiseless.append(coefs)
        
    return np.asarray(coefs_pauli_group), np.asarray(coefs_pauli_group_noiseless)

# %%
scaler = MinMaxScaler()
coefs_pauli_NN_list = []
coefs_pauli_AD_list = []
coefs_pauli_DP_list = []
coefs_pauli_PD_list = []
coefs_pauli_TR_list = []
num_gates_list = [5,10,20]
num_samples = 4000
embedding_NN_list = []
embedding_AD_list = []
embedding_DP_list = []
embedding_PD_list = []
embedding_TR_list = []
umap_modNN = umap.UMAP(random_state=1234)
umap_modAD = umap.UMAP(random_state=1234)
umap_modDP = umap.UMAP(random_state=1234)
umap_modPD = umap.UMAP(random_state=1234)
umap_modTR = umap.UMAP(random_state=1234)


for num_gates in num_gates_list:
    coefs_pauli_NN,_ = pauli_group_span('G3', nqbits=2, num_samples=num_samples, num_gates = num_gates, 
                                      err_type=None)
    coefs_pauli_AD,_ = pauli_group_span('G3', nqbits=2, num_samples=num_samples, num_gates = num_gates, 
                                      err_type='amplitude_damping', err_p1=0.2, err_p2=0.2)
    coefs_pauli_DP,_ = pauli_group_span('G3', nqbits=2, num_samples=num_samples, num_gates = num_gates, 
                                      err_type='depolarizing', err_p1=0.2, err_p2=0.2)
    coefs_pauli_PD,_ = pauli_group_span('G3', nqbits=2, num_samples=num_samples, num_gates = num_gates, 
                                      err_type='phase_damping', err_p1=0.2, err_p2=0.2)
    coefs_pauli_TR,_ = pauli_group_span('G3', nqbits=2, num_samples=num_samples, num_gates = num_gates, 
                                      err_type='thermal_relaxation', t1=488e-9, t2=683e-9)
    
    embedding_NN = umap_modNN.fit_transform(np.hstack([np.real(coefs_pauli_NN), np.imag(coefs_pauli_NN)]))
    embedding_AD = umap_modAD.fit_transform(np.hstack([np.real(coefs_pauli_AD), np.imag(coefs_pauli_AD)]))
    embedding_DP = umap_modDP.fit_transform(np.hstack([np.real(coefs_pauli_DP), np.imag(coefs_pauli_DP)]))
    embedding_PD = umap_modPD.fit_transform(np.hstack([np.real(coefs_pauli_PD), np.imag(coefs_pauli_PD)]))
    embedding_TR = umap_modPD.fit_transform(np.hstack([np.real(coefs_pauli_TR), np.imag(coefs_pauli_TR)]))

    embedding_NN = scaler.fit_transform(embedding_NN)
    embedding_AD = scaler.fit_transform(embedding_AD)
    embedding_DP = scaler.fit_transform(embedding_DP)
    embedding_PD = scaler.fit_transform(embedding_PD)
    embedding_TR = scaler.fit_transform(embedding_TR)
    
    coefs_pauli_NN_list.append(coefs_pauli_NN)
    coefs_pauli_AD_list.append(coefs_pauli_AD)
    coefs_pauli_DP_list.append(coefs_pauli_DP)
    coefs_pauli_PD_list.append(coefs_pauli_PD)
    coefs_pauli_TR_list.append(coefs_pauli_TR)
    
    embedding_NN_list.append(embedding_NN)
    embedding_AD_list.append(embedding_AD)
    embedding_DP_list.append(embedding_DP)
    embedding_PD_list.append(embedding_PD)
    embedding_TR_list.append(embedding_TR)

# Random    
#pauli_group_matrices = np.asarray(pauli_basis(2).to_matrix())
#coefs_random = np.random.rand(num_samples, (pauli_group_matrices.shape[0], pauli_group_matrices.shape[0]) \
#               + 1j*np.random.rand(num_samples, (pauli_group_matrices.shape[0], pauli_group_matrices.shape[0])))
#embedding_random = umap_mod.fit_transform(np.hstack([np.real(coefs_random), np.imag(coefs_random)]))
#embedding_random = scaler.fit_transform(embedding_random)
# Out:
# 100%|█████████████████████████████████████████████████████| 4000/4000 [07:24<00:00,  8.99it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:18<00:00, 10.58it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:09<00:00, 10.84it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:01<00:00, 11.06it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:10<00:00, 10.79it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [07:13<00:00,  9.22it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:12<00:00, 10.74it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:08<00:00, 10.87it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:09<00:00, 10.82it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:03<00:00, 11.01it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [07:49<00:00,  8.52it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:17<00:00, 10.61it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:17<00:00, 10.59it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [05:53<00:00, 11.31it/s]
# 100%|█████████████████████████████████████████████████████| 4000/4000 [06:14<00:00, 10.67it/s]

# %%
embedding_NN_list = np.array(embedding_NN_list)
embedding_AD_list = np.array(embedding_AD_list)
embedding_DP_list = np.array(embedding_DP_list)
embedding_PD_list = np.array(embedding_PD_list)
embedding_TR_list = np.array(embedding_TR_list)

# with open('embedding_noiseless.pickle', 'wb') as f:
#     pickle.dump(embedding_NN_list,f)
    
# with open('embedding_AD.pickle', 'wb') as f:
#     pickle.dump(embedding_AD_list,f)
    
# with open('embedding_DP.pickle', 'wb') as f:
#     pickle.dump(embedding_DP_list,f)
    
# with open('embedding_PD.pickle', 'wb') as f:
#     pickle.dump(embedding_PD_list,f)

# with open('embedding_TR.pickle', 'wb') as f:
#     pickle.dump(embedding_TR_list,f)

# %%
colors = ['lightskyblue', 'lightcoral', 'turquoise', 'thistle', 'lightgreen']
labels = ['Noiseless', 'Amplitude damping', 'Depolarizing', 'Phase damping', 'Thermal relaxation']

fig, ax = plt.subplots(1,2,figsize=(10, 5))


ln1 = ax[0].scatter(embedding_NN_list[1,:,0], embedding_NN_list[1,:,1], color=colors[1])
t1 = ax[0].text(0,0.97, "Noiseless",fontsize=20)
t1.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='black'))

##########################################################################################

# ax[0,1].scatter(embedding_AD_list[1,:,0], embedding_AD_list[1,:,1], cmap='Spectral', color=colors[0])
# t2 = ax[0,1].text(0.0,0.97, "Amplitude damping",fontsize=14)
# t2.set_bbox(dict(facecolor='white', alpha=0.9, edgecolor='black'))

# ax[1,0].scatter(embedding_DP_list[1,:,0], embedding_DP_list[1,:,1], cmap='Spectral', color=colors[2])
# t3 = ax[1,0].text(0,0.97, "Depolarizing",fontsize=14)
# t3.set_bbox(dict(facecolor='white', alpha=0.9, edgecolor='black'))

# ax[1,1].scatter(embedding_PD_list[1,:,0], embedding_PD_list[1,:,1], cmap='Spectral', color=colors[3])
# t4 = ax[1,1].text(0,0.97, "Phase damping",fontsize=14)
# t4.set_bbox(dict(facecolor='white', alpha=0.9, edgecolor='black'))

ax[1].scatter(embedding_TR_list[1,:,0], embedding_TR_list[1,:,1], cmap='Spectral', color=colors[3])
t5 = ax[1].text(0,0.97, "Thermal relaxation",fontsize=20)
t5.set_bbox(dict(facecolor='white', alpha=0.9, edgecolor='black'))

#lgnd = plt.legend([ln1, ln2, ln3, ln4], labels, bbox_to_anchor = (1,3))
#for handle in lgnd.legendHandles:
#    handle.set_sizes([30])
    
plt.subplots_adjust(wspace=0, hspace=0)
plt.setp(ax, xticks=[], yticks=[])

fig.tight_layout()
plt.savefig('pauli_space_noise.png', format='png')
plt.show()

# %% [markdown]
# ## 5. Example coefficients
#
# In this example we show how the amplitude damping noise apart from mitigating the coefficients in the Pauli space, also introduces new non-zero coefficients. We create an example with the same toy model and visualize the coefficients of the distribution in the Pauli space for the four error models, together with the noiseless circuits.

# %%
paulis = pauli_basis(2)
paulis_mat = [p.to_matrix() for p in paulis]

# No errors
qc_tot = QuantumCircQiskit('G3', num_gates=10,nqbits=2,observables_type = 'all', err_type=None)
#  Create quanutm circuit only ONCE!
qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc_tot.apply_G_gates(qc)
qubits = [i for i in range(qc.num_qubits)]
qc.append(SaveDensityMatrix(qc.num_qubits, label=f'rho'), qubits)


# No noise
backend = AerSimulator(method='density_matrix')
job = transpile(qc, backend)
result_noise = backend.run(qc, shots=1024).result()
density_matrix = np.array(result_noise.data()['rho'])
coefs_noiseless = [np.trace(density_matrix @ p).real for p in paulis_mat]


# Amplitude damping
qc_tot = QuantumCircQiskit('G3', num_gates=10,nqbits=2,observables_type = 'all', err_type='amplitude_damping',err_p1=0.2, err_p2=0.2)
backend = AerSimulator(method='density_matrix',noise_model=qc_tot.noise_model,basis_gates=qc_tot.basis_gates)
job = transpile(qc, backend)
result_noise = backend.run(qc, shots=1024).result()
density_matrix = np.array(result_noise.data()['rho'])
coefs_amplitude_damping = [np.trace(density_matrix @ p).real for p in paulis_mat]

# Depolarizing
qc_tot = QuantumCircQiskit('G3', num_gates=10,nqbits=2,observables_type = 'all', err_type='depolarizing',err_p1=0.2, err_p2=0.2)
backend = AerSimulator(method='density_matrix',noise_model=qc_tot.noise_model,basis_gates=qc_tot.basis_gates)
job = transpile(qc, backend)
result_noise = backend.run(qc, shots=1024).result()
density_matrix = np.array(result_noise.data()['rho'])
coefs_depolarizing = [np.trace(density_matrix @ p).real for p in paulis_mat]

# Phase damping
qc_tot = QuantumCircQiskit('G3', num_gates=10,nqbits=2,observables_type = 'all', err_type='phase_damping',err_p1=0.2, err_p2=0.2)
backend = AerSimulator(method='density_matrix',noise_model=qc_tot.noise_model,basis_gates=qc_tot.basis_gates)
job = transpile(qc, backend)
result_noise = backend.run(qc, shots=1024).result()
density_matrix = np.array(result_noise.data()['rho'])
coefs_phase_damping = [np.trace(density_matrix @ p).real for p in paulis_mat]

# Thermal_relaxation
qc_tot = QuantumCircQiskit('G3', num_gates=10,nqbits=2,observables_type = 'all', err_type='thermal_relaxation',t1=488e-9, t2=683e-9)
backend = AerSimulator(method='density_matrix',noise_model=qc_tot.noise_model,basis_gates=qc_tot.basis_gates)
job = transpile(qc, backend)
result_noise = backend.run(qc, shots=1024).result()
density_matrix = np.array(result_noise.data()['rho'])
coefs_thermal_relaxation = [np.trace(density_matrix @ p).real for p in paulis_mat]


# with open('coefs_noiseless.pickle', 'wb') as f:
#     pickle.dump(coefs_noiseless,f)
    
# with open('coefs_amplitude_damping.pickle', 'wb') as f:
#     pickle.dump(coefs_amplitude_damping,f)
    
# with open('coefs_depolarizing.pickle', 'wb') as f:
#     pickle.dump(coefs_depolarizing,f)
    
# with open('coefs_phase_damping.pickle', 'wb') as f:
#     pickle.dump(coefs_phase_damping,f)

# with open('coefs_thermal_relaxation.pickle', 'wb') as f:
#     pickle.dump(coefs_thermal_relaxation,f)

# %%
#idx+=2
fig = plt.figure(figsize=(10,8))
plt.plot(coefs_noiseless, linewidth=2, marker='o', color='black', label='noiseless')
plt.plot(coefs_amplitude_damping, marker='o', label='amplitude damping')
plt.plot(coefs_depolarizing, marker='o', label='depolarizing')
plt.plot(coefs_phase_damping, marker='o', label='phase damping')
plt.plot(coefs_thermal_relaxation, marker='o', label='thermal relaxation')
plt.xlabel('Pauli basis index', fontsize=14)
plt.ylabel('Expected value', fontsize=14)
plt.title('Noise effect on the Pauli space distribution', fontsize=16)
plt.legend(fontsize=12, framealpha=1)
plt.fill_between([2,6],[-1.1,-1.1], [1.1,1.1], alpha=0.1, color='gray')
plt.fill_between([10,13],[-1.1,-1.1], [1.1,1.1], alpha=0.1, color='gray')
plt.ylim(-1.1,1.1)

fig.tight_layout()
plt.savefig('noise_effect.png', format='png')
plt.show()
